# %%
#import pickle files
import pickle
import pandas as pd
import numpy as np


# import SEM_svr_linear.pkl
with open('SEM_svr_linear.pickle', 'rb') as file:
    SEM_svr_linear = pickle.load(file)

# import SEM_svr_rbf.pkl
with open('SEM_svr_rbf.pickle', 'rb') as file:
    SEM_svr_rbf = pickle.load(file)

# # import SEM_svr_poly.pkl
# with open('SEM_svr_poly.pkl', 'rb') as file:
#     SEM_svr_poly = pickle.load(file)

# import SEM_svr_sigmoid.pkl
with open('SEM_svr_sigmoid.pickle', 'rb') as file:
    SEM_svr_sigmoid = pickle.load(file)

# %%
df = pd.concat([SEM_svr_linear, SEM_svr_rbf, SEM_svr_sigmoid], axis=0)

# %%
df
# Out:
#            ds     vintage_file  Estimate        Model
# 0  2018-04-01  vintage_2018_05  0.006609   SVR_LINEAR
# 1  2018-04-01  vintage_2018_06  0.008841   SVR_LINEAR
# 2  2018-04-01  vintage_2018_07  0.009342   SVR_LINEAR
# 3  2018-07-01  vintage_2018_08  0.004938   SVR_LINEAR
# 4  2018-07-01  vintage_2018_09  0.007457   SVR_LINEAR
# ..        ...              ...       ...          ...
# 52 2022-07-01  vintage_2022_09  0.001395  SVR_SIGMOID
# 53 2022-07-01  vintage_2022_10  0.005703  SVR_SIGMOID
# 54 2022-10-01  vintage_2022_11 -0.000077  SVR_SIGMOID
# 55 2022-10-01  vintage_2022_12  0.004280  SVR_SIGMOID
# 56 2022-10-01  vintage_2023_01  0.004520  SVR_SIGMOID
#
# [171 rows x 4 columns]

# %%
# export df to csv
df.to_csv('tidy_svr.csv', index=False)
